# %% [markdown]
# # **Psychology Chatbot**

# %% [markdown]
# ## **Import necessary modules**

# %%
# Deep learning framework for neural network operations
import tensorflow as tf
# High-level neural networks API (runs on top of TensorFlow)
from tensorflow import keras

# JSON handling for data serialization/deserialization
import json
# Facebook's FAISS library for efficient similarity search
import faiss
# Numerical computing library for array/matrix operations
import numpy as np

# Client library for interacting with Ollama's LLM API
import ollama
# Sentence embedding models and similarity utilities
from sentence_transformers import SentenceTransformer, util

# Speech recognition library for microphone input
import speech_recognition as sr
# Text-to-speech conversion library
import pyttsx3

# Operating system interfaces for file/path operations
import os
# HTTP requests library for web API calls
import requests

# Text feature extraction (for bag-of-words/tf-idf)
from sklearn.feature_extraction.text import CountVectorizer

# GPT-2 model and tokenizer for perplexity evaluation
from transformers import GPT2LMHeadModel, GPT2TokenizerFast

# PyTorch deep learning framework
import torch
# Mathematical operations and constants
import math

# Evaluation metrics library
import evaluate
# ROUGE metric for text generation evaluation
rouge = evaluate.load("rouge")
# BLEU score metric for machine translation evaluation
bleu = evaluate.load("bleu")

# %% [markdown]
# ## **Data Loading, Embedding Generation, and FAISS Indexing**

# %%
# Load the dataset
with open(r"C:\Users\Vidhi\ML Chatbot\data\unified_dataset.json", "r", encoding="utf-8") as file:
    data = json.load(file)

# Initialize embedding model (Use a model optimized for retrieval)
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Extract questions and answers
texts = [entry["Title"] + " " + entry["Content"] for entry in data]

# Generate embeddings
embeddings = embedding_model.encode(texts, convert_to_numpy=True)

# Store in FAISS
dimension = embeddings.shape[1]  # Get embedding size
index = faiss.IndexFlatL2(dimension)  # Create FAISS index
index.add(embeddings)  # Add embeddings to FAISS

# Save FAISS index
faiss.write_index(index, "faiss_index.bin")

# Save data mapping (to retrieve original texts)
with open("data_mapping.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=4)

print("FAISS index and data mapping saved!")
# Out:
# C:\Users\Vidhi\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Vidhi\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# FAISS index and data mapping saved!

# %% [markdown]
# ## **RAG-Powered Chatbot with Conversation Memory**

# %%
# Configure Ollama client
tt_client = ollama.Client(host='http://localhost:11435')  # Change port if needed

# Load FAISS index and data
index = faiss.read_index("faiss_index.bin")
with open("data_mapping.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Load embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# File to store chat memory
MEMORY_FILE = "chat_memory.json"

def load_chat_memory():
    if os.path.exists(MEMORY_FILE):
        with open(MEMORY_FILE, "r", encoding="utf-8") as f:
            return json.load(f)
    return []

def save_chat_memory():
    with open(MEMORY_FILE, "w", encoding="utf-8") as f:
        json.dump(chat_memory, f, indent=4)

# Initialize memory
chat_memory = load_chat_memory()

def search_faiss(query, top_k=3):
    query_embedding = embedding_model.encode([query], convert_to_numpy=True)
    _, indices = index.search(query_embedding, top_k)
    retrieved_texts = [data[i] for i in indices[0]]
    return retrieved_texts

def psychology_chatbot(query):
    retrieved_docs = search_faiss(query)
    context = "\n".join([doc["Title"] + ": " + doc["Content"][:300] + "..." for doc in retrieved_docs])
    memory_context = "\n".join([f"Q: {item['question']}\nA: {item['answer']}" for item in chat_memory[-3:]])
    
    prompt = f"""You are an AI psychology assistant. Answer based on the given knowledge:
    Previous Conversation:
    {memory_context}
    
    Current Context:
    {context}
    
    User Query: {query}
    Response:"""

    response = tt_client.chat(
        model="mistral", 
        messages=[{"role": "user", "content": prompt}]
    )
    
    answer = response["message"]["content"]
    
    chat_memory.append({"question": query, "answer": answer})
    save_chat_memory()
    
    return answer

def get_chat_memory():
    return chat_memory

# Speech-to-Text (STT)
def speech_to_text():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio)
    except sr.UnknownValueError:
        return "Could not understand audio."
    except sr.RequestError:
        return "Error with speech recognition service."

# Text-to-Speech (TTS)
def text_to_speech(text):
    engine = pyttsx3.init()
    engine.say(text)
    engine.runAndWait()

# %% [markdown]
# ## **User Input Processing and Response Generation**

# %%
if __name__ == "__main__":
    while True:
        user_input = input("Enter your query (or say 'voice input' to speak, 'exit' to quit): ")
        
        if user_input.lower() == "exit":
            break
        elif user_input.lower() == "show memory":
            for i, entry in enumerate(get_chat_memory(), 1):
                print(f"{i}. Q: {entry['question']}\n   A: {entry['answer']}\n")
            continue
        elif user_input.lower() == "voice input":
            user_input = speech_to_text()
            print("You said:", user_input)
        
        if user_input and user_input.lower() not in ["show memory", "exit"]:
            response = psychology_chatbot(user_input)
            print("Bot:", response)
            text_to_speech(response)
            print("\n")
# Out:
# Enter your query (or say 'voice input' to speak, 'exit' to quit):  what is mental health
# Bot:  Mental health refers to a state of well-being in which an individual can realize their own abilities, cope with the normal stresses of life, work productively and fruitfully, and make contributions to their community. It involves having beliefs, thoughts, feelings, and behaviors that allow you to live in harmony with yourself and others. Mental health is not just the absence of mental disorders or illnesses; it's a positive state that encompasses emotional, psychological, and social well-being.
# Enter your query (or say 'voice input' to speak, 'exit' to quit):  exit

# %% [markdown]
# ## **Semantic Similarity Scoring**

# %%
def score_retrieval(query):
    query_embedding = embedding_model.encode(query, convert_to_tensor=True)
    retrieved_docs = search_faiss(query)
    scores = []

    for i, doc in enumerate(retrieved_docs, 1):
        chunk_text = doc["Title"] + " " + doc["Content"]
        chunk_embedding = embedding_model.encode(chunk_text, convert_to_tensor=True)
        score = util.pytorch_cos_sim(query_embedding, chunk_embedding).item()
        scores.append((i, score, doc["Title"]))
    
    return scores

# %%
with open("chatbot_eval_output.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)

for item in eval_data:
    query = item["question"]
    scores = score_retrieval(query)
    for i, score, title in scores:
        print(f"#{i} | Title: {title} | Similarity Score: {score:.2f}")
    print()
# Out:
# #1 | Title: WHAT IS PSYCHOLOGY? | Similarity Score: 0.74
# #2 | Title: PSYCHOLOGY AND OTHER DISCIPLINES | Similarity Score: 0.70
# #3 | Title: Psychology as a Natural Science | Similarity Score: 0.67
#
# #1 | Title: Nature of Stress | Similarity Score: 0.73
# #2 | Title: Nature, Types, and Sources of Stress | Similarity Score: 0.68
# #3 | Title: Psychological Stress | Similarity Score: 0.67
#
# #1 | Title: What is mental health? | Similarity Score: 0.80
# #2 | Title: What's the difference between mental health and mental illness? | Similarity Score: 0.69
# #3 | Title: What does it mean to have a mental illness? | Similarity Score: 0.65
#
# #1 | Title: Behaviorism: Focus on Observable Behavior | Similarity Score: 0.73
# #2 | Title: What is behaviour? | Similarity Score: 0.61
# #3 | Title: Situationism and Behavioural Variations | Similarity Score: 0.58
#
# #1 | Title: Cognitive Psychology | Similarity Score: 0.71
# #2 | Title: Psychology as a Natural Science | Similarity Score: 0.57
# #3 | Title: The Rise of Cognitive Psychology and Constructivism | Similarity Score: 0.56
#
# #1 | Title: Motivation | Similarity Score: 0.79
# #2 | Title: NATURE OF MOTIVATION | Similarity Score: 0.71
# #3 | Title: The Motivational Cycle | Similarity Score: 0.61
#
# #1 | Title: Nature of emotions | Similarity Score: 0.70
# #2 | Title: I don't know how to have emotions. I never had any from my birth. Being human, I think of myself as a monster. I enjoy pain. I cut myself for my climax during sex. I think most of the time, I lie, even when sometimes it would have been easy just to tell the truth. I was in rehabilitation for four year. I have made love with both men and women, but it made no impact in my emotions. The books that I enjoy reading H.P. Lovecraft and Edgar Allen Poe. I go hunting every Saturday. I feel powerful. I don't enjoy the killing of the creature, but the hunt of it and to eat and drink the flesh and blood of the creature. | Similarity Score: 0.61
# #3 | Title: I don't know how to have emotions. I never had any from my birth. Being human, I think of myself as a monster. I enjoy pain. I cut myself for my climax during sex. I think most of the time, I lie, even when sometimes it would have been easy just to tell the truth. I was in rehabilitation for four year. I have made love with both men and women, but it made no impact in my emotions. The books that I enjoy reading H.P. Lovecraft and Edgar Allen Poe. I go hunting every Saturday. I feel powerful. I don't enjoy the killing of the creature, but the hunt of it and to eat and drink the flesh and blood of the creature. | Similarity Score: 0.61
#
# #1 | Title: Developmental Psychology | Similarity Score: 0.80
# #2 | Title: Meaning of Development | Similarity Score: 0.60
# #3 | Title: Stages of Personality Development | Similarity Score: 0.58
#
# #1 | Title: Nature of Memory | Similarity Score: 0.71
# #2 | Title: Methods of Memory Measurement | Similarity Score: 0.60
# #3 | Title: Storage in memory | Similarity Score: 0.59
#
# #1 | Title: Gestalt Psychology: Holistic Perception | Similarity Score: 0.56
# #2 | Title: Environmental Influences on Perception | Similarity Score: 0.54
# #3 | Title: Sensory Memory | Similarity Score: 0.48
#
# #1 | Title: Key Learning Processes in Operant Conditioning | Similarity Score: 0.68
# #2 | Title: Classical Conditioning Learning | Similarity Score: 0.64
# #3 | Title: Determinants of Operant Conditioning Learning | Similarity Score: 0.61
#
# #1 | Title: Determinants of Operant Conditioning Learning | Similarity Score: 0.73
# #2 | Title: Key Learning Processes in Operant Conditioning | Similarity Score: 0.71
# #3 | Title: Operant/Instrumental Conditioning Learning | Similarity Score: 0.62
#
# #1 | Title: Intelligence | Similarity Score: 0.78
# #2 | Title: Theories of intelligence | Similarity Score: 0.70
# #3 | Title: Culture and intelligence | Similarity Score: 0.64
#
# #1 | Title: Anxiety Disorder | Similarity Score: 0.69
# #2 | Title: Examination Anxiety | Similarity Score: 0.68
# #3 | Title: What’s the difference between anxiety and an anxiety disorder? | Similarity Score: 0.66
#
# #1 | Title: Stigma and Misunderstandings about Psychological Disorders | Similarity Score: 0.68
# #2 | Title: Misconceptions and Stigma | Similarity Score: 0.65
# #3 | Title: Classification of Psychological Disorders | Similarity Score: 0.65
#
# #1 | Title: Types of Psychologists | Similarity Score: 0.64
# #2 | Title: Medicine | Similarity Score: 0.63
# #3 | Title: Competencies for Psychologists | Similarity Score: 0.61
#
# #1 | Title: Self-Concept | Similarity Score: 0.77
# #2 | Title: Components of Self-Concept | Similarity Score: 0.75
# #3 | Title: Concept of Self | Similarity Score: 0.65
#
# #1 | Title: Understanding mind and behaviour | Similarity Score: 0.57
# #2 | Title: Levels of Consciousness | Similarity Score: 0.50
# #3 | Title: Psychoanalysis: The Unconscious Mind | Similarity Score: 0.47
#
# #1 | Title: Self and Personality | Similarity Score: 0.67
# #2 | Title: Concept of Personality | Similarity Score: 0.64
# #3 | Title: Trait Approaches | Similarity Score: 0.62
#
# #1 | Title: Maslow's Hierarchy of Needs | Similarity Score: 0.82
# #2 | Title: Maslow’s hierarchy of needs | Similarity Score: 0.76
# #3 | Title: Bronfenbrenner's Contextual View of Development | Similarity Score: 0.47
#
# #1 | Title: Rosenzweig’s Picture-Frustration Study (P-F Study) | Similarity Score: 0.40
# #2 | Title: What can I do about my boyfriend's verbal abuse? | Similarity Score: 0.39
# #3 | Title: How do I start talking again after a fight? | Similarity Score: 0.37
#
# #1 | Title: Social Psychology | Similarity Score: 0.76
# #2 | Title: Explaining Social Behaviour | Similarity Score: 0.63
# #3 | Title: Psychology in Everyday Life | Similarity Score: 0.58
#
# #1 | Title: Commonly Abused Substances | Similarity Score: 0.33
# #2 | Title: Physiological Effects of stress | Similarity Score: 0.31
# #3 | Title: Message Characteristics of attitude | Similarity Score: 0.30
#
# #1 | Title: Theories Supporting Behavioural Approach | Similarity Score: 0.64
# #2 | Title: Observational Learning | Similarity Score: 0.57
# #3 | Title: Paradigms of Learning | Similarity Score: 0.57
#
# #1 | Title: Neuropsychology | Similarity Score: 0.65
# #2 | Title: Biological Factors Causing Abnormal Behaviour | Similarity Score: 0.51
# #3 | Title: Biological Factors that cause abnormal behaviour | Similarity Score: 0.50
#
# #1 | Title: Emotional intelligence | Similarity Score: 0.83
# #2 | Title: Enhance Self-Awareness | Similarity Score: 0.64
# #3 | Title: Intelligence | Similarity Score: 0.62
#
# #1 | Title: Attention in psychological services | Similarity Score: 0.69
# #2 | Title: Control Processes in Memory | Similarity Score: 0.50
# #3 | Title: Observational Skills | Similarity Score: 0.46
#
# #1 | Title: Promoting Positive Health and Well-being | Similarity Score: 0.56
# #2 | Title: Psychology in Everyday Life | Similarity Score: 0.50
# #3 | Title: Preventive Measures for Natural Disasters | Similarity Score: 0.49
#
# #1 | Title: Learned Helplessness | Similarity Score: 0.77
# #2 | Title: Preparedness for Learning | Similarity Score: 0.51
# #3 | Title: Stress Resistant Personality | Similarity Score: 0.48
#
# #1 | Title: What's the difference between a psychiatrist and a registered psychologist? | Similarity Score: 0.66
# #2 | Title: Clinical and Counselling Psychology | Similarity Score: 0.65
# #3 | Title: Developing as an Effective Psychologist | Similarity Score: 0.57

# %% [markdown]
# ## **Keyword Overlap**
# Extract keywords from the query and check how many appear in the retrieved chunk.

# %%
def keyword_overlap_score(query):
    retrieved_docs = search_faiss(query)
    for doc in retrieved_docs:
        doc_text = doc["Title"] + " " + doc["Content"]
        vectorizer = CountVectorizer().fit([query])
        query_vector = vectorizer.transform([query]).toarray()
        doc_vector = vectorizer.transform([doc_text]).toarray()
        overlap_score = np.minimum(query_vector, doc_vector).sum()
        print(f"Title: {doc['Title']}, Overlap Score: {overlap_score}")
    print()

# %%
with open("chatbot_eval_output.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)

for item in eval_data:
    query = item["question"]
    keyword_overlap_score(query)
# Out:
# Title: WHAT IS PSYCHOLOGY?, Overlap Score: 3
# Title: PSYCHOLOGY AND OTHER DISCIPLINES, Overlap Score: 1
# Title: Psychology as a Natural Science, Overlap Score: 3
#
# Title: Nature of Stress, Overlap Score: 2
# Title: Nature, Types, and Sources of Stress, Overlap Score: 2
# Title: Psychological Stress, Overlap Score: 2
#
# Title: What is mental health?, Overlap Score: 4
# Title: What's the difference between mental health and mental illness?, Overlap Score: 4
# Title: What does it mean to have a mental illness?, Overlap Score: 4
#
# Title: Behaviorism: Focus on Observable Behavior, Overlap Score: 2
# Title: What is behaviour?, Overlap Score: 1
# Title: Situationism and Behavioural Variations, Overlap Score: 1
#
# Title: Cognitive Psychology, Overlap Score: 2
# Title: Psychology as a Natural Science, Overlap Score: 2
# Title: The Rise of Cognitive Psychology and Constructivism, Overlap Score: 2
#
# Title: Motivation, Overlap Score: 2
# Title: NATURE OF MOTIVATION, Overlap Score: 3
# Title: The Motivational Cycle, Overlap Score: 1
#
# Title: Nature of emotions, Overlap Score: 2
# Title: I don't know how to have emotions. I never had any from my birth. Being human, I think of myself as a monster. I enjoy pain. I cut myself for my climax during sex. I think most of the time, I lie, even when sometimes it would have been easy just to tell the truth. I was in rehabilitation for four year. I have made love with both men and women, but it made no impact in my emotions. The books that I enjoy reading H.P. Lovecraft and Edgar Allen Poe. I go hunting every Saturday. I feel powerful. I don't enjoy the killing of the creature, but the hunt of it and to eat and drink the flesh and blood of the creature., Overlap Score: 3
# Title: I don't know how to have emotions. I never had any from my birth. Being human, I think of myself as a monster. I enjoy pain. I cut myself for my climax during sex. I think most of the time, I lie, even when sometimes it would have been easy just to tell the truth. I was in rehabilitation for four year. I have made love with both men and women, but it made no impact in my emotions. The books that I enjoy reading H.P. Lovecraft and Edgar Allen Poe. I go hunting every Saturday. I feel powerful. I don't enjoy the killing of the creature, but the hunt of it and to eat and drink the flesh and blood of the creature., Overlap Score: 3
#
# Title: Developmental Psychology, Overlap Score: 3
# Title: Meaning of Development, Overlap Score: 1
# Title: Stages of Personality Development, Overlap Score: 1
#
# Title: Nature of Memory, Overlap Score: 2
# Title: Methods of Memory Measurement, Overlap Score: 2
# Title: Storage in memory, Overlap Score: 2
#
# Title: Gestalt Psychology: Holistic Perception, Overlap Score: 2
# Title: Environmental Influences on Perception, Overlap Score: 2
# Title: Sensory Memory, Overlap Score: 1
#
# Title: Key Learning Processes in Operant Conditioning, Overlap Score: 2
# Title: Classical Conditioning Learning, Overlap Score: 2
# Title: Determinants of Operant Conditioning Learning, Overlap Score: 1
#
# Title: Determinants of Operant Conditioning Learning, Overlap Score: 2
# Title: Key Learning Processes in Operant Conditioning, Overlap Score: 2
# Title: Operant/Instrumental Conditioning Learning, Overlap Score: 3
#
# Title: Intelligence, Overlap Score: 2
# Title: Theories of intelligence, Overlap Score: 2
# Title: Culture and intelligence, Overlap Score: 2
#
# Title: Anxiety Disorder, Overlap Score: 2
# Title: Examination Anxiety, Overlap Score: 2
# Title: What’s the difference between anxiety and an anxiety disorder?, Overlap Score: 3
#
# Title: Stigma and Misunderstandings about Psychological Disorders, Overlap Score: 3
# Title: Misconceptions and Stigma, Overlap Score: 3
# Title: Classification of Psychological Disorders, Overlap Score: 3
#
# Title: Types of Psychologists, Overlap Score: 3
# Title: Medicine, Overlap Score: 4
# Title: Competencies for Psychologists, Overlap Score: 3
#
# Title: Self-Concept, Overlap Score: 3
# Title: Components of Self-Concept, Overlap Score: 2
# Title: Concept of Self, Overlap Score: 3
#
# Title: Understanding mind and behaviour, Overlap Score: 4
# Title: Levels of Consciousness, Overlap Score: 4
# Title: Psychoanalysis: The Unconscious Mind, Overlap Score: 4
#
# Title: Self and Personality, Overlap Score: 1
# Title: Concept of Personality, Overlap Score: 2
# Title: Trait Approaches, Overlap Score: 2
#
# Title: Maslow's Hierarchy of Needs, Overlap Score: 4
# Title: Maslow’s hierarchy of needs, Overlap Score: 4
# Title: Bronfenbrenner's Contextual View of Development, Overlap Score: 1
#
# Title: Rosenzweig’s Picture-Frustration Study (P-F Study), Overlap Score: 4
# Title: What can I do about my boyfriend's verbal abuse?, Overlap Score: 3
# Title: How do I start talking again after a fight?, Overlap Score: 5
#
# Title: Social Psychology, Overlap Score: 2
# Title: Explaining Social Behaviour, Overlap Score: 3
# Title: Psychology in Everyday Life, Overlap Score: 3
#
# Title: Commonly Abused Substances, Overlap Score: 1
# Title: Physiological Effects of stress, Overlap Score: 2
# Title: Message Characteristics of attitude, Overlap Score: 3
#
# Title: Theories Supporting Behavioural Approach, Overlap Score: 2
# Title: Observational Learning, Overlap Score: 2
# Title: Paradigms of Learning, Overlap Score: 2
#
# Title: Neuropsychology, Overlap Score: 4
# Title: Biological Factors Causing Abnormal Behaviour, Overlap Score: 5
# Title: Biological Factors that cause abnormal behaviour, Overlap Score: 4
#
# Title: Emotional intelligence, Overlap Score: 3
# Title: Enhance Self-Awareness, Overlap Score: 4
# Title: Intelligence, Overlap Score: 2
#
# Title: Attention in psychological services, Overlap Score: 3
# Title: Control Processes in Memory, Overlap Score: 3
# Title: Observational Skills, Overlap Score: 2
#
# Title: Promoting Positive Health and Well-being, Overlap Score: 3
# Title: Psychology in Everyday Life, Overlap Score: 3
# Title: Preventive Measures for Natural Disasters, Overlap Score: 0
#
# Title: Learned Helplessness, Overlap Score: 3
# Title: Preparedness for Learning, Overlap Score: 2
# Title: Stress Resistant Personality, Overlap Score: 3
#
# Title: What's the difference between a psychiatrist and a registered psychologist?, Overlap Score: 8
# Title: Clinical and Counselling Psychology, Overlap Score: 4
# Title: Developing as an Effective Psychologist, Overlap Score: 6

# %% [markdown]
# #### Generating answers of "evaluation_set.json" using chatbot

# %%
# Load the dataset
with open("evaluation_set.json", "r", encoding="utf-8") as f:
    dataset = json.load(f)

# Lists to store results
questions = []
expected_answers = []
generated_answers = []

# Process each entry
for entry in dataset:
    question = entry["question"]
    expected_answer = entry["answer"]
    generated_answer = psychology_chatbot(question)

    questions.append(question)
    expected_answers.append(expected_answer)
    generated_answers.append(generated_answer)

    print(f"Q: {question}\nExpected: {expected_answer[:100]}...\nGenerated: {generated_answer[:100]}...\n")

# Save the results to a JSON file
results = [
    {"question": q, "expected_answer": e, "generated_answer": g}
    for q, e, g in zip(questions, expected_answers, generated_answers)
]

with open("chatbot_eval_output.json", "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4)

print("\nStored all results in 'chatbot_eval_output.json'")
# Out:
# Q: what is psychology
# Expected: Psychology is a scientific discipline that studies the behavior, thoughts, emotions, and mental proc...
# Generated:  Psychology is a knowledge discipline that focuses on understanding human behavior, thoughts, and fe...
#
# Q: what is stress
# Expected: Stress is a pattern of responses that an organism makes to events that disturb its equilibrium......
# Generated:  Stress refers to the pattern of responses an organism makes to events that disturb its equilibrium ...
#
# Q: what is mental health
# Expected: Mental health refers to a person’s emotional, psychological, and social well-being. It influences ho...
# Generated:  Mental health refers to an individual's beliefs, thoughts, feelings, and behaviors regarding their ...
#
# Q: define behaviorism in psychology
# Expected: Behaviorism is a theoretical orientation in psychology that focuses on observable behaviors rather t...
# Generated:  In psychology, Behaviorism is a theoretical perspective developed by John Watson around 1910. It fo...
#
# Q: explain cognitive psychology
# Expected: Cognitive psychology studies mental processes such as perception, memory, reasoning, problem-solving...
# Generated:  Cognitive Psychology is a branch of psychology that focuses on understanding the mental processes i...
#
# Q: what is motivation
# Expected: Motivation is the internal process that initiates, guides, and sustains goal-directed behaviors......
# Generated:  Motivation is a fundamental factor that drives behavior and is both a mental and physiological stat...
#
# Q: what are emotions
# Expected: Emotions are complex psychological states that involve physiological arousal, expressive behaviors, ...
# Generated:  Emotions are a complex pattern of arousal, subjective feeling, and cognitive interpretation that ar...
#
# Q: what is developmental psychology
# Expected: Developmental psychology is the study of how people grow and change from infancy through old age......
# Generated:  Developmental Psychology is a branch of psychology that focuses on understanding physical, social, ...
#
# Q: what is memory
# Expected: Memory is the mental capacity to store, retain, and recall information over time......
# Generated:  Memory is the ability to retain and recall information or experiences over a period of time. It inv...
#
# Q: what is perception
# Expected: Perception is the process of organizing and interpreting sensory information to make it meaningful.....
# Generated:  Perception refers to the process by which individuals interpret and make sense of sensory informati...
#
# Q: explain classical conditioning
# Expected: Classical conditioning is a learning process where a natural response becomes associated with a prev...
# Generated:  Classical Conditioning is a learning process discovered by Ivan Pavlov in which an initially neutra...
#
# Q: what is operant conditioning
# Expected: Operant conditioning is a method of learning that occurs through rewards and punishments for behavio...
# Generated:  Operant Conditioning is a type of learning process discovered by B.F. Skinner, where behaviors are ...
#
# Q: define intelligence in psychology
# Expected: Intelligence is the ability to acquire and apply knowledge and skills, solve problems, and adapt to ...
# Generated:  In psychology, intelligence refers to the ability to adapt to and navigate one's environment effect...
#
# Q: what is anxiety
# Expected: Anxiety is a feeling of worry, nervousness, or unease about an imminent event or something with an u...
# Generated:  Anxiety refers to feelings of tension, worry, or unease about events, objects, or situations that a...
#
# Q: what are psychological disorders
# Expected: Psychological disorders are patterns of behavioral or psychological symptoms that impact multiple ar...
# Generated:  Psychological disorders, also known as mental health disorders or mental illnesses, refer to signif...
#
# Q: what is the role of a psychologist
# Expected: A psychologist studies mental processes and behavior, and helps people manage problems through couns...
# Generated:  The role of a psychologist can vary depending on their specialization, but generally, they aim to u...
#
# Q: what is self-concept
# Expected: Self-concept is an individual’s perception of self, encompassing beliefs, feelings, and thoughts abo...
# Generated:  Self-concept refers to the overall perception an individual has of themselves and the ideas they ho...
#
# Q: what is the unconscious mind
# Expected: The unconscious mind is a reservoir of feelings, thoughts, urges, and memories outside of conscious ...
# Generated:  The Unconscious Mind refers to the part of an individual's mind that consists of all the thoughts, ...
#
# Q: what is personality
# Expected: Personality is the combination of characteristics or qualities that form an individual’s distinctive...
# Generated:  Personality refers to the characteristic patterns of thinking, feeling, and behaving that make each...
#
# Q: explain Maslow's hierarchy of needs
# Expected: Maslow's hierarchy of needs is a motivational theory comprising five levels of human needs, from phy...
# Generated:  Maslow's Hierarchy of Needs is a psychological theory that outlines a hierarchy of five categories ...
#
# Q: what is the fight or flight response
# Expected: The fight or flight response is the body’s automatic reaction to perceived danger, preparing to conf...
# Generated:  The Fight or Flight response, also known as Acute Stress Response (ASR), is a physiological reactio...
#
# Q: what is social psychology
# Expected: Social psychology studies how individuals think, feel, and behave in social contexts and how others ...
# Generated:  Social Psychology is a branch of psychology that explores how individuals are influenced by their s...
#
# Q: what is the placebo effect
# Expected: The placebo effect is the phenomenon in which patients experience real changes in their health after...
# Generated:  The Placebo Effect refers to a phenomenon in which individuals experience improvement in their symp...
#
# Q: define observational learning
# Expected: Observational learning is the process of learning behaviors by watching and imitating others......
# Generated:  Observational Learning, as defined in your provided context, refers to a process by which individua...
#
# Q: what is the role of neurotransmitters
# Expected: Neurotransmitters are chemical messengers that transmit signals between neurons and affect mood, aro...
# Generated:  Neurotransmitters play a crucial role in neuropsychology by transmitting signals between different ...
#
# Q: what is emotional intelligence
# Expected: Emotional intelligence is the ability to recognize, understand, manage, and use emotions effectively...
# Generated:  Emotional Intelligence refers to a set of abilities that enable individuals to recognize, understan...
#
# Q: what is attention
# Expected: Attention is the cognitive process of selectively concentrating on one aspect of the environment whi...
# Generated:  Attention refers to the cognitive process by which individuals focus on a specific stimulus or set ...
#
# Q: what is resilience in psychology
# Expected: Resilience is the ability to adapt well and recover quickly from stress, adversity, trauma, or trage...
# Generated:  In psychology, resilience refers to an individual's capacity to adapt successfully in the face of s...
#
# Q: what is learned helplessness
# Expected: Learned helplessness is a condition in which a person feels unable to control or change a situation ...
# Generated:  Learned Helplessness is a psychological concept that refers to a state where an individual has been...
#
# Q: what is the difference between psychologist and psychiatrist
# Expected: A psychologist provides therapy and conducts assessments, while a psychiatrist is a medical doctor w...
# Generated:  A Psychologist and a Psychiatrist both work in the field of mental health, but they have different ...
#
#
# Stored all results in 'chatbot_eval_output.json'

# %% [markdown]
# ## **Similarity-Based Accuracy Function**
# * Use cosine similarity between:
# * The chatbot’s response (generated_answer)
# * The ground truth answer (expected_answer)

# %%
def compute_accuracy():
    with open("chatbot_eval_output.json", "r", encoding="utf-8") as f:
        eval_data = json.load(f)
    
    total = len(eval_data)
    score_sum = 0
    threshold = 0.7  # Define your acceptance threshold

    for item in eval_data:
        question = item["question"]
        expected_answer = item["expected_answer"]
        generated_answer = item["generated_answer"]

        # Convert to embeddings
        emb_expected = embedding_model.encode(expected_answer, convert_to_tensor=True)
        emb_generated = embedding_model.encode(generated_answer, convert_to_tensor=True)

        # Compute cosine similarity
        similarity = util.pytorch_cos_sim(emb_expected, emb_generated).item()

        print(f"\nQ: {question}\nExpected: {expected_answer[:100]}...\nGenerated: {generated_answer[:100]}...\nSimilarity: {similarity:.2f}")

        # Accuracy = % of responses above threshold
        score_sum += 1 if similarity >= threshold else 0

    accuracy = (score_sum / total) * 100
    print(f"\nOverall Accuracy: {accuracy:.2f}%")

# %%
compute_accuracy()
# Out:
# Q: what is psychology
# Expected: Psychology is the scientific study of the mind, behavior, and mental processes. It seeks to understa...
# Generated:  Psychology is a knowledge discipline that focuses on understanding human behavior, thoughts, and fe...
# Similarity: 0.77
#
# Q: what is stress
# Expected: Stress is the body's physiological and psychological response to perceived threats or demands, known...
# Generated:  Stress refers to the pattern of responses an organism makes to events that disturb its equilibrium ...
# Similarity: 0.79
#
# Q: what is mental health
# Expected: Mental health encompasses emotional, psychological, and social well-being, influencing how individua...
# Generated:  Mental health refers to an individual's beliefs, thoughts, feelings, and behaviors regarding their ...
# Similarity: 0.79
#
# Q: define behaviorism in psychology
# Expected: Behaviorism is a psychological theory emphasizing observable behaviors over internal mental states. ...
# Generated:  In psychology, Behaviorism is a theoretical perspective developed by John Watson around 1910. It fo...
# Similarity: 0.76
#
# Q: explain cognitive psychology
# Expected: Cognitive psychology examines mental processes like perception, memory, problem-solving, and decisio...
# Generated:  Cognitive Psychology is a branch of psychology that focuses on understanding the mental processes i...
# Similarity: 0.67
#
# Q: what is motivation
# Expected: Motivation refers to the internal and external factors driving goal-directed behavior. It involves b...
# Generated:  Motivation is a fundamental factor that drives behavior and is both a mental and physiological stat...
# Similarity: 0.69
#
# Q: what are emotions
# Expected: Emotions are complex psychological and physiological states triggered by stimuli, involving subjecti...
# Generated:  Emotions are a complex pattern of arousal, subjective feeling, and cognitive interpretation that ar...
# Similarity: 0.69
#
# Q: what is developmental psychology
# Expected: Developmental psychology studies human growth across the lifespan, from infancy to old age. It exami...
# Generated:  Developmental Psychology is a branch of psychology that focuses on understanding physical, social, ...
# Similarity: 0.59
#
# Q: what is memory
# Expected: Memory is the cognitive process of encoding, storing, and retrieving information. It involves three ...
# Generated:  Memory is the ability to retain and recall information or experiences over a period of time. It inv...
# Similarity: 0.72
#
# Q: what is perception
# Expected: Perception is the process of organizing and interpreting sensory information to construct meaningful...
# Generated:  Perception refers to the process by which individuals interpret and make sense of sensory informati...
# Similarity: 0.75
#
# Q: explain classical conditioning
# Expected: Classical conditioning, pioneered by Ivan Pavlov, is learning where a neutral stimulus becomes assoc...
# Generated:  Classical Conditioning is a learning process discovered by Ivan Pavlov in which an initially neutra...
# Similarity: 0.83
#
# Q: what is operant conditioning
# Expected: Operant Conditioning is a psychological learning process developed by B.F. Skinner, which emphasizes...
# Generated:  Operant Conditioning is a type of learning process discovered by B.F. Skinner, where behaviors are ...
# Similarity: 0.89
#
# Q: define intelligence in psychology
# Expected: In psychology, intelligence is broadly defined as the mental capacity to acquire knowledge, learn fr...
# Generated:  In psychology, intelligence refers to the ability to adapt to and navigate one's environment effect...
# Similarity: 0.66
#
# Q: what is anxiety
# Expected: Anxiety is a psychological and physiological state characterized by feelings of worry, nervousness, ...
# Generated:  Anxiety refers to feelings of tension, worry, or unease about events, objects, or situations that a...
# Similarity: 0.85
#
# Q: what are psychological disorders
# Expected: Psychological disorders, also known as mental disorders or mental illnesses, are patterns of abnorma...
# Generated:  Psychological disorders, also known as mental health disorders or mental illnesses, refer to signif...
# Similarity: 0.89
#
# Q: what is the role of a psychologist
# Expected: A psychologist is a trained professional who studies human behavior and mental processes to understa...
# Generated:  The role of a psychologist can vary depending on their specialization, but generally, they aim to u...
# Similarity: 0.78
#
# Q: what is self-concept
# Expected: Self-concept refers to the comprehensive perception individuals have of themselves, encompassing the...
# Generated:  Self-concept refers to the overall perception an individual has of themselves and the ideas they ho...
# Similarity: 0.86
#
# Q: what is the unconscious mind
# Expected: The unconscious mind is a concept in psychology that refers to the part of the mind that operates ou...
# Generated:  The Unconscious Mind refers to the part of an individual's mind that consists of all the thoughts, ...
# Similarity: 0.95
#
# Q: what is personality
# Expected: Personality refers to the unique set of traits, behaviors, thoughts, and emotional patterns that con...
# Generated:  Personality refers to the characteristic patterns of thinking, feeling, and behaving that make each...
# Similarity: 0.78
#
# Q: explain Maslow's hierarchy of needs
# Expected: Maslow's hierarchy of needs is a psychological theory proposed by Abraham Maslow in 1943 that outlin...
# Generated:  Maslow's Hierarchy of Needs is a psychological theory that outlines a hierarchy of five categories ...
# Similarity: 0.82
#
# Q: what is the fight or flight response
# Expected: The fight or flight response is a physiological and psychological reaction that occurs in response t...
# Generated:  The Fight or Flight response, also known as Acute Stress Response (ASR), is a physiological reactio...
# Similarity: 0.71
#
# Q: what is social psychology
# Expected: Social psychology is a branch of psychology that focuses on how individuals’ thoughts, feelings, and...
# Generated:  Social Psychology is a branch of psychology that explores how individuals are influenced by their s...
# Similarity: 0.91
#
# Q: what is the placebo effect
# Expected: The placebo effect is a psychological phenomenon in which a person experiences real or perceived imp...
# Generated:  The Placebo Effect refers to a phenomenon in which individuals experience improvement in their symp...
# Similarity: 0.85
#
# Q: define observational learning
# Expected: Observational learning, also known as modeling or social learning, is a process through which indivi...
# Generated:  Observational Learning, as defined in your provided context, refers to a process by which individua...
# Similarity: 0.93
#
# Q: what is the role of neurotransmitters
# Expected: Neurotransmitters are chemical messengers in the brain and nervous system that transmit signals betw...
# Generated:  Neurotransmitters play a crucial role in neuropsychology by transmitting signals between different ...
# Similarity: 0.89
#
# Q: what is emotional intelligence
# Expected: Emotional intelligence (EI), also known as emotional quotient (EQ), refers to the capacity to recogn...
# Generated:  Emotional Intelligence refers to a set of abilities that enable individuals to recognize, understan...
# Similarity: 0.77
#
# Q: what is attention
# Expected: Attention is a fundamental cognitive process that involves selectively focusing on specific informat...
# Generated:  Attention refers to the cognitive process by which individuals focus on a specific stimulus or set ...
# Similarity: 0.87
#
# Q: what is resilience in psychology
# Expected: Resilience in psychology refers to an individual's ability to adapt positively and recover from adve...
# Generated:  In psychology, resilience refers to an individual's capacity to adapt successfully in the face of s...
# Similarity: 0.96
#
# Q: what is learned helplessness
# Expected: Learned helplessness is a psychological condition in which an individual believes they have no contr...
# Generated:  Learned Helplessness is a psychological concept that refers to a state where an individual has been...
# Similarity: 0.87
#
# Q: what is the difference between psychologist and psychiatrist
# Expected: The primary difference between a psychologist and a psychiatrist lies in their education, training, ...
# Generated:  A Psychologist and a Psychiatrist both work in the field of mental health, but they have different ...
# Similarity: 0.90
#
# Overall Accuracy: 83.33%

# %% [markdown]
# ## **ROUGE / BLEU for Deeper Evaluation**

# %%
def evaluate_nlp_metrics():
    with open("chatbot_eval_output.json", "r", encoding="utf-8") as f:
        eval_data = json.load(f)

    refs, preds = [], []

    for item in eval_data:
        question = item["question"]
        expected = item["expected_answer"]
        generated = item["generated_answer"]

        refs.append(expected)
        preds.append(generated)

    print("ROUGE:", rouge.compute(predictions=preds, references=refs))
    print("\nBLEU:", bleu.compute(predictions=preds, references=[[ref] for ref in refs]))

# %%
evaluate_nlp_metrics()
# Out:
# ROUGE: {'rouge1': np.float64(0.4089562372622777), 'rouge2': np.float64(0.1266339231744525), 'rougeL': np.float64(0.23011940110539927), 'rougeLsum': np.float64(0.24400745090586576)}
#
# BLEU: {'bleu': 0.10136881548267056, 'precisions': [0.4516276937184778, 0.14750692520775624, 0.06183170618317062, 0.03347378277153558], 'brevity_penalty': 0.9354640925264084, 'length_ratio': 0.9374597034171502, 'translation_length': 4362, 'reference_length': 4653}

# %% [markdown]
# ## **Perplexity Evaluation**
# * Perplexity is a common metric used to evaluate how well a language model predicts a sequence of words. It essentially measures the "surprise" of the model when it sees the actual next word in a sequence.
# * A low perplexity score means the model is less surprised and is doing a good job at predicting the text.
# * A high perplexity means the model is more surprised, so it's performing poorly.

# %%
# Load GPT-2 model and tokenizer
model_name = "gpt2"
tokenizer = GPT2TokenizerFast.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
model.eval()  # Set model to evaluation mode (disables dropout)

# Function to compute perplexity of a given text
def compute_perplexity(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs, labels=inputs["input_ids"])
        loss = outputs.loss
    return math.exp(loss.item())

# Evaluate perplexity for multiple chatbot responses
def evaluate_chatbot_perplexity(eval_set_path="chatbot_eval_output.json"):
    with open(eval_set_path, "r", encoding="utf-8") as f:
        eval_data = json.load(f)

    perplexities = []

    for item in eval_data:
        question = item["question"]
        generated_answer = item["generated_answer"]

        try:
            perplexity = compute_perplexity(generated_answer)
            perplexities.append(perplexity)
            print(f"Q: {question}\nA: {generated_answer[:100]}...\nPerplexity: {perplexity:.2f}\n")
        except Exception as e:
            print(f"Error with input: {generated_answer[:50]}... | {str(e)}")
    
    if perplexities:
        avg_perplexity = sum(perplexities) / len(perplexities)
        print(f"\nAverage Perplexity Score: {avg_perplexity:.2f}")
    else:
        print("\nNo responses could be evaluated.")

# %%
evaluate_chatbot_perplexity()
# Out:
# Q: what is psychology
# A:  Psychology is a knowledge discipline that focuses on understanding human behavior, thoughts, and fe...
# Perplexity: 15.26
#
# Q: what is stress
# A:  Stress refers to the pattern of responses an organism makes to events that disturb its equilibrium ...
# Perplexity: 23.66
#
# Q: what is mental health
# A:  Mental health refers to an individual's beliefs, thoughts, feelings, and behaviors regarding their ...
# Perplexity: 10.88
#
# Q: define behaviorism in psychology
# A:  In psychology, Behaviorism is a theoretical perspective developed by John Watson around 1910. It fo...
# Perplexity: 32.95
#
# Q: explain cognitive psychology
# A:  Cognitive Psychology is a branch of psychology that focuses on understanding the mental processes i...
# Perplexity: 13.30
#
# Q: what is motivation
# A:  Motivation is a fundamental factor that drives behavior and is both a mental and physiological stat...
# Perplexity: 29.96
#
# Q: what are emotions
# A:  Emotions are a complex pattern of arousal, subjective feeling, and cognitive interpretation that ar...
# Perplexity: 14.12
#
# Q: what is developmental psychology
# A:  Developmental Psychology is a branch of psychology that focuses on understanding physical, social, ...
# Perplexity: 11.95
#
# Q: what is memory
# A:  Memory is the ability to retain and recall information or experiences over a period of time. It inv...
# Perplexity: 22.52
#
# Q: what is perception
# A:  Perception refers to the process by which individuals interpret and make sense of sensory informati...
# Perplexity: 25.23
#
# Q: explain classical conditioning
# A:  Classical Conditioning is a learning process discovered by Ivan Pavlov in which an initially neutra...
# Perplexity: 20.45
#
# Q: what is operant conditioning
# A:  Operant Conditioning is a type of learning process discovered by B.F. Skinner, where behaviors are ...
# Perplexity: 13.92
#
# Q: define intelligence in psychology
# A:  In psychology, intelligence refers to the ability to adapt to and navigate one's environment effect...
# Perplexity: 17.77
#
# Q: what is anxiety
# A:  Anxiety refers to feelings of tension, worry, or unease about events, objects, or situations that a...
# Perplexity: 13.24
#
# Q: what are psychological disorders
# A:  Psychological disorders, also known as mental health disorders or mental illnesses, refer to signif...
# Perplexity: 10.38
#
# Q: what is the role of a psychologist
# A:  The role of a psychologist can vary depending on their specialization, but generally, they aim to u...
# Perplexity: 9.40
#
# Q: what is self-concept
# A:  Self-concept refers to the overall perception an individual has of themselves and the ideas they ho...
# Perplexity: 15.43
#
# Q: what is the unconscious mind
# A:  The Unconscious Mind refers to the part of an individual's mind that consists of all the thoughts, ...
# Perplexity: 20.17
#
# Q: what is personality
# A:  Personality refers to the characteristic patterns of thinking, feeling, and behaving that make each...
# Perplexity: 24.56
#
# Q: explain Maslow's hierarchy of needs
# A:  Maslow's Hierarchy of Needs is a psychological theory that outlines a hierarchy of five categories ...
# Perplexity: 13.76
#
# Q: what is the fight or flight response
# A:  The Fight or Flight response, also known as Acute Stress Response (ASR), is a physiological reactio...
# Perplexity: 11.81
#
# Q: what is social psychology
# A:  Social Psychology is a branch of psychology that explores how individuals are influenced by their s...
# Perplexity: 20.45
#
# Q: what is the placebo effect
# A:  The Placebo Effect refers to a phenomenon in which individuals experience improvement in their symp...
# Perplexity: 19.51
#
# Q: define observational learning
# A:  Observational Learning, as defined in your provided context, refers to a process by which individua...
# Perplexity: 25.77
#
# Q: what is the role of neurotransmitters
# A:  Neurotransmitters play a crucial role in neuropsychology by transmitting signals between different ...
# Perplexity: 8.99
#
# Q: what is emotional intelligence
# A:  Emotional Intelligence refers to a set of abilities that enable individuals to recognize, understan...
# Perplexity: 13.53
#
# Q: what is attention
# A:  Attention refers to the cognitive process by which individuals focus on a specific stimulus or set ...
# Perplexity: 20.41
#
# Q: what is resilience in psychology
# A:  In psychology, resilience refers to an individual's capacity to adapt successfully in the face of s...
# Perplexity: 14.99
#
# Q: what is learned helplessness
# A:  Learned Helplessness is a psychological concept that refers to a state where an individual has been...
# Perplexity: 17.71
#
# Q: what is the difference between psychologist and psychiatrist
# A:  A Psychologist and a Psychiatrist both work in the field of mental health, but they have different ...
# Perplexity: 9.71
#
#
# Average Perplexity Score: 17.39
